# %%
import requests
import re
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

# %%
# change URL base on the category
BASE_URL = 'https://www.betclic.fr/'
URL = 'https://www.betclic.fr/tennis-s2'

def get_match_links(url: str=URL) -> dict:

    response = requests.get(url)
    if response.status_code == 200:
        
        soup = BeautifulSoup(response.text, 'html.parser')
        href_attributes = [BASE_URL+a.get('href') for a in soup.find_all('a') if '/tennis-s2/' in a.get('href')]
        matchs_link = [href.encode('ascii', 'ignore').decode('unicode_escape') for href in href_attributes]

        return {"Error": False, "links": matchs_link}
    else:
        return{"Error": True, "Message": f"Unable to retrieve the webpage. Status code: {response.status_code}"}  

def create_tennis_driver(link: str):

    # set up Chrome driver
    options = Options()
    #options.add_argument('--no-sandbox')
    #options.add_argument('--headless')
    #options.add_argument('--disable-gpu')
    #options.add_argument('--disable-dev-shm-usage')

    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

    # Navigate to the webpage you want to scrape
    driver.get(link)

    try:
        # coockies
        driver.find_element("xpath", '//*[@id="popin_tc_privacy_button_2"]').click()
        driver.implicitly_wait(1)
        # click to "points et service"
        x_path = '//*[@id="matchHeader"]/div/sports-category-filters/bcdk-tabs/div/div/div/div[last()]/span'
        driver.find_element("xpath", x_path).click()
        driver.implicitly_wait(2)
        return driver
    
    except Exception as e:
        return None  

def retrieve_tennis_point_service(driver: webdriver):
    class_name = 'block'
    point_service = driver.find_element(By.CLASS_NAME, class_name)
    info = point_service.text
    return info

# %%
if __name__ == '__main__':
    
    match_links = get_match_links()

    if match_links.get('Error'):
        print("we have a problem of too many requests")
    else:
        links = match_links.get('links')

    all_text = []

    for url in links[:5]:
        driver = create_tennis_driver(url)
        if driver is None:
            continue
        else:
            info = retrieve_tennis_point_service(driver)
            try:
                result = re.search(r'Aces(.*?)0 selection', info, re.DOTALL)
                if result:
                    extracted_text = result.group(1).strip()
                    print(extracted_text)
                all_text.append(extracted_text)
            except Exception:
                print("no Aces found")
    text = '|'.join(elm for elm in all_text)

    # Writing to a file
    with open("tennis_data.txt", "w") as file:
        file.write(text)
# Out:
# no Aces found
# Points
# Vainqueur Point 4 (Set 2, Jeu 12)
# A. Mannarino
# 2,25
# M. Giron
# 1,35
# Aces
# Plus grand nombre d'aces
# A. Mannarino
# 7,00
# Nul
# 5,00
# M. Giron
# 1,10
# Nombre total d'aces dans le match
# + de 12,5
# 1,70
# - de 12,5
# 1,70
# Nombre d'aces inscrits par le joueur 1 dans le match
# + de 5.5
# 1,50
# - de 5.5
# 1,90
# Nombre d'aces inscrits par le joueur 2 dans le match
# + de 7.5
# 1,70
# - de 7.5
# 1,70
# Jeux de service
# Aces
# Vainqueur du match et Nombre total d'aces
# Taylor Fritz et + de 14,5
# 2,10
# Taylor Fritz et - de 14,5
# 2,10
# Nuno Borges et + de 14,5
# 7,00
# Nuno Borges et - de 14.5
# 7,00
# Premier ace
# Taylor Fritz
# 1,18
# Nuno Borges
# 3,25
# Plus grand nombre d'aces
# Taylor Fritz
# 1,01
# Nul
# 8,00
# Nuno Borges
# 8,00
# Nombre total d'aces dans le match
# + de 14.5
# 1,70
# - de 14.5
# 1,70
# Nombre d'aces inscrits par le joueur 1 dans le match
# + de 9.5
# 1,70
# - de 9.5
# 1,70
# Nombre d'aces inscrits par le joueur 2 dans le match
# + de 4.5
# 1,70
# - de 4.5
# 1,70
# Jeux de service
# Score exact sur le 1er jeu de service Taylor Fritz
# Taylor Fritz Vainqueur blanc
# 3,75
# Taylor Fritz Vainqueur à 15
# 3,00
# Taylor Fritz Vainqueur à 30
# 3,50
# Score exact sur le 1er jeu de service Nuno Borges
# Nuno Borges Vainqueur blanc
# 6,00
# Nuno Borges Vainqueur à 15
# 4,00
# Nuno Borges Vainqueur à 30
# 4,00
# Serveur qui remporte son premier jeu de service à 0/15/30
# Taylor Fritz, Oui
# 1,20
# Nuno Borges, Oui
# 1,60
# Taylor Fritz, Non
# 3,00
# Nuno Borges, Non
# 1,88
# Taylor Fritz - Premier jeu de service - Nombre total de points
# 4
# 2,50
# 5
# 2,80
# 6
# 3,50
# Plus de 6 Points
# 5,00
# Nuno Borges - Premier jeu de service - Nombre total de points
# 4
# 5,00
# 5
# 2,75
# 6
# 3,25
# Plus de 6 Points
# 3,00
# Taylor Fritz - Score De Son 1ER Jeu De Service Apres 2 Points
# Taylor Fritz 30-0
# 1,55
# 15-15
# 2,20
# Nuno Borges 30-0
# 12
# Joueur 1 - Score de son 1er jeu de service apres 3 points
# Taylor Fritz 40-0
# 1,90
# Taylor Fritz 30-15
# 1,80
# Nuno Borges 40-0
# 30
# Nuno Borges 30-15
# 5,00
# Joueur 1 - Score de son 1er jeu de service après 4 points
# Taylor Fritz gagne son jeu à 0
# 2,75
# Taylor Fritz 40-15
# 1,80
# 30-30
# 3,50
# Joueur 2 - Score de son 1er jeu de service après 2 Points
# Nuno Borges 30-0
# 2,25
# 15-15
# 1,75
# Taylor Fritz 30-0
# 5,00
# Joueur 2 - Score de son 1er jeu de service après 3 points
# Nuno Borges 40-0
# 3,25
# Nuno Borges 30-15
# 2,10
# Taylor Fritz 40-0
# 10
# Taylor Fritz 30-15
# 2,75
# Joueur 2 - Score de son 1er jeu de service après 4 points
# Nuno Borges gagne son jeu à 0
# 4,25
# Nuno Borges 40-15
# 2,40
# 30-30
# 2,50
# Jeux de service
# Aces
# Vainqueur du match et Nombre total d'aces
# Grigor Dimitrov et + de 8,5
# 2,20
# Grigor Dimitrov et - de 8,5
# 2,20
# Marton Fucsovics et + de 8.5
# 6,00
# Marton Fucsovics et - de 8.5
# 6,00
# Premier ace
# Grigor Dimitrov
# 1,60
# Marton Fucsovics
# 1,88
# Plus grand nombre d'aces
# Grigor Dimitrov
# 1,60
# Nul
# 8,00
# Marton Fucsovics
# 2,00
# Nombre total d'aces dans le match
# + de 8.5
# 1,70
# - de 8.5
# 1,70
# Nombre d'aces inscrits par le joueur 1 dans le match
# + de 4.5
# 1,70
# - de 4.5
# 1,70
# Nombre d'aces inscrits par le joueur 2 dans le match
# + de 4.5
# 2,00
# - de 4.5
# 1,52
# Jeux de service
# Score exact sur le 1er jeu de service Grigor Dimitrov
# Grigor Dimitrov Vainqueur blanc
# 3,75
# Grigor Dimitrov Vainqueur à 15
# 3,10
# Grigor Dimitrov Vainqueur à 30
# 3,50
# Score exact sur le 1er jeu de service Marton Fucsovics
# Marton Fucsovics Vainqueur blanc
# 5,50
# Marton Fucsovics Vainqueur à 15
# 4,00
# Marton Fucsovics Vainqueur à 30
# 4,00
# Serveur qui remporte son premier jeu de service à 0/15/30
# Grigor Dimitrov, Oui
# 1,25
# Marton Fucsovics, Oui
# 1,50
# Grigor Dimitrov, Non
# 2,75
# Marton Fucsovics, Non
# 2,05
# Grigor Dimitrov - Premier jeu de service - Nombre total de points
# 4
# 3,00
# 5
# 2,80
# 6
# 3,15
# Plus de 6 Points
# 4,00
# Marton Fucsovics - Premier jeu de service - Nombre total de points
# 4
# 4,50
# 5
# 2,75
# 6
# 3,25
# Plus de 6 Points
# 3,00
# Grigor Dimitrov - Score De Son 1ER Jeu De Service Apres 2 Points
# Grigor Dimitrov 30-0
# 1,60
# 15-15
# 2,15
# Marton Fucsovics 30-0
# 10
# Joueur 1 - Score de son 1er jeu de service apres 3 points
# Grigor Dimitrov 40-0
# 2,00
# Grigor Dimitrov 30-15
# 1,80
# Marton Fucsovics 40-0
# 25
# Marton Fucsovics 30-15
# 5,00
# Joueur 1 - Score de son 1er jeu de service après 4 points
# Grigor Dimitrov gagne son jeu à 0
# 3,00
# Grigor Dimitrov 40-15
# 1,80
# 30-30
# 3,50
# Joueur 2 - Score de son 1er jeu de service après 2 Points
# Marton Fucsovics 30-0
# 2,25
# 15-15
# 1,75
# Grigor Dimitrov 30-0
# 5,00
# Joueur 2 - Score de son 1er jeu de service après 3 points
# Marton Fucsovics 40-0
# 3,00
# Marton Fucsovics 30-15
# 2,00
# Grigor Dimitrov 40-0
# 12
# Grigor Dimitrov 30-15
# 3,00
# Joueur 2 - Score de son 1er jeu de service après 4 points
# Marton Fucsovics gagne son jeu à 0
# 4,00
# Marton Fucsovics 40-15
# 2,25
# 30-30
# 2,60
# Jeux de service
# Aces
# Vainqueur du match et Nombre total d'aces
# Alexander Shevchenko et + de 12,5
# 6,00
# Alexander Shevchenko et - de 12.5
# 6,00
# Holger Vitus Nodskov Rune et + de 12.5
# 2,20
# Holger Vitus Nodskov Rune et - de 12,5
# 2,20
# Premier ace
# Alexander Shevchenko
# 2,20
# Holger Vitus Nodskov Rune
# 1,45
# Plus grand nombre d'aces
# Alexander Shevchenko
# 4,00
# Nul
# 6,00
# Holger Vitus Nodskov Rune
# 1,20
# Nombre total d'aces dans le match
# + de 12,5
# 1,70
# - de 12,5
# 1,70
# Nombre d'aces inscrits par le joueur 1 dans le match
# + de 4.5
# 1,70
# - de 4.5
# 1,70
# Nombre d'aces inscrits par le joueur 2 dans le match
# + de 7.5
# 1,70
# - de 7.5
# 1,70
# Jeux de service
# Score exact sur le 1er jeu de service Alexander Shevchenko
# Alexander Shevchenko Vainqueur blanc
# 5,00
# Alexander Shevchenko Vainqueur à 15
# 3,75
# Alexander Shevchenko Vainqueur à 30
# 4,00
# Score exact sur le 1er jeu de service Holger Vitus Nodskov Rune
# Holger Vitus Nodskov Rune Vainqueur blanc
# 3,75
# Holger Vitus Nodskov Rune Vainqueur à 15
# 3,10
# Holger Vitus Nodskov Rune Vainqueur à 30
# 3,60
# Serveur qui remporte son premier jeu de service à 0/15/30
# Alexander Shevchenko, Oui
# 1,50
# Holger Vitus Nodskov Rune, Oui
# 1,25
# Alexander Shevchenko, Non
# 2,05
# Holger Vitus Nodskov Rune, Non
# 2,75
# Alexander Shevchenko - Premier jeu de service - Nombre total de points
# 4
# 4,50
# 5
# 2,75
# 6
# 3,25
# Plus de 6 Points
# 3,00
# Holger Vitus Nodskov Rune - Premier jeu de service - Nombre total de points
# 4
# 3,00
# 5
# 2,80
# 6
# 3,15
# Plus de 6 Points
# 4,00
# Alexander Shevchenko - Score De Son 1ER Jeu De Service Apres 2 Points
# Alexander Shevchenko 30-0
# 2,20
# 15-15
# 1,80
# Holger Vitus Nodskov Rune 30-0
# 6,00
# Joueur 1 - Score de son 1er jeu de service apres 3 points
# Alexander Shevchenko 40-0
# 3,00
# Alexander Shevchenko 30-15
# 2,00
# Holger Vitus Nodskov Rune 40-0
# 12
# Holger Vitus Nodskov Rune 30-15
# 3,00
# Joueur 1 - Score de son 1er jeu de service après 4 points
# Alexander Shevchenko gagne son jeu à 0
# 4,00
# Alexander Shevchenko 40-15
# 2,30
# 30-30
# 2,50
# Joueur 2 - Score de son 1er jeu de service après 2 Points
# Holger Vitus Nodskov Rune 30-0
# 1,65
# 15-15
# 2,15
# Alexander Shevchenko 30-0
# 10
# Joueur 2 - Score de son 1er jeu de service après 3 points
# Holger Vitus Nodskov Rune 40-0
# 2,00
# Holger Vitus Nodskov Rune 30-15
# 1,80
# Alexander Shevchenko 40-0
# 25
# Alexander Shevchenko 30-15
# 5,00
# Joueur 2 - Score de son 1er jeu de service après 4 points
# Holger Vitus Nodskov Rune gagne son jeu à 0
# 3,00
# Holger Vitus Nodskov Rune 40-15
# 1,80
# 30-30
# 3,50
